# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Final_table.csv')
data.head()
# Out:
#    datetime_beginning_ept  MIDATL_solar  OTHER_solar  RFC_solar  RTO_solar  \
# 0  18/02/2022 00:00:00 AM         0.282          0.0      0.041     -4.019
# 1  18/02/2022 01:00:00 AM         0.246          0.0     -0.006     -4.236
# 2  18/02/2022 02:00:00 AM         0.300          0.0      0.060     -4.067
# 3  18/02/2022 03:00:00 AM         0.254          0.0      0.015     -3.981
# 4  18/02/2022 04:00:00 AM         0.270          0.0      0.034     -4.057
#
#    SOUTH_solar  WEST_solar  MIDATL_wind  OTHER_wind  RFC_wind  ...  \
# 0       -4.061      -0.240      957.466         NaN  5625.364  ...
# 1       -4.230      -0.252      939.014         NaN  5291.098  ...
# 2       -4.128      -0.239      904.381         NaN  4676.792  ...
# 3       -3.996      -0.239      889.508         NaN  3968.681  ...
# 4       -4.092      -0.235      863.901         NaN  3413.737  ...
#
#    DOM_forecast  DUQ_forecast  EKPC_forecast  MIDATL_forecast  RTO_forecast  \
# ...
